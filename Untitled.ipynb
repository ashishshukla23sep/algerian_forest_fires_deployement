# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pickle
import joblib
import pymongo

# %%
df=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/00547/Algerian_forest_fires_dataset_UPDATE.csv")

# %% [markdown]
# # Data Cleaning

# %%
#Removing multiindexing
df.reset_index(level=list(range(0,len(df.index[0]))),inplace=True)
df.columns=df.iloc[0].str.strip()
df['Classes']=df['Classes'].str.strip()
df.drop(index=df[df['Classes']=='Classes'].index,inplace=True)

# %%
df.head()
# Out:
# 0 day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 1  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 2  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 3  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 4  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 5  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
# 0   Classes
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire
# 5  not fire

# %% [markdown]
# ## Attribute Information:
# 1. Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012)
# Weather data observations
# 2. Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42
# 3. RH : Relative Humidity in %: 21 to 90
# 4. Ws :Wind speed in km/h: 6 to 29
# 5. Rain: total day in mm: 0 to 16.8
# FWI Components
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# 7. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# 8. Drought Code (DC) index from the FWI system: 7 to 220.4
# 9. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# 10. Buildup Index (BUI) index from the FWI system: 1.1 to 68
# 11. Fire Weather Index (FWI) Index: 0 to 31.1
# 12. Classes: two classes, namely NOT FIRE and FIRE

# %% [markdown]
# # 1.Handling missing values

# %%
#missing value
df.isnull().sum()
# Out:
# 0
# day            0
# month          1
# year           1
# Temperature    1
# RH             1
# Ws             1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df['Classes'].unique()
# Out:
# array(['not fire', 'fire', nan], dtype=object)

# %%
df.Classes=df.Classes.map({'fire':1,'not fire':0})

# %%
df.Classes.fillna('null',inplace=True)

# %%
df[df.Classes=='null']
# Out:
# 0                              day month  year Temperature   RH   Ws Rain  \
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN  NaN
# 168                             14    07  2012          37   37   18  0.2
#
# 0    FFMC   DMC      DC   ISI   BUI      FWI Classes
# 123   NaN   NaN     NaN   NaN   NaN      NaN    null
# 168  88.9  12.9  14.6 9  12.5  10.4  fire       null

# %%
#since we have only 1 valid nan in classes feature so we will drop that from training data and we

# %%
df.drop(index=df[df.Classes=='null'].index,inplace=True)

# %%
df.isnull().sum()
# Out:
# 0
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# dtype: int64

# %% [markdown]
# # Handling categorical and numerical variable

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 1 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
# dtypes: object(14)
# memory usage: 28.5+ KB

# %%
# Converting all the variable in Float
for i in df.columns:
    df[i]=df[i].astype('float')
df.Classes=df.Classes.astype('int')#output in int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 1 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    float64
#  1   month        243 non-null    float64
#  2   year         243 non-null    float64
#  3   Temperature  243 non-null    float64
#  4   RH           243 non-null    float64
#  5   Ws           243 non-null    float64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    int32
# dtypes: float64(13), int32(1)
# memory usage: 27.5 KB

# %% [markdown]
# # EDA Regression (FWI as aTarget)

# %%
pd.set_option("display.max_rows",df.shape[0]-1)

# %%
df.describe()
# Out:
# 0             day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
# 0            Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %% [markdown]
# ### Univariate Analysis

# %%
import warnings
warnings.filterwarnings(action='ignore')
for i in df.columns:
    if i!='year':
        sns.distplot(df[i])
        plt.show()
        print("Skewness: %f" %df[i].skew())
        print("Kurtosis: %f" %df[i].kurt())
# Out:
# Skewness: 0.000365
# Kurtosis: -1.205600
# Skewness: -0.005207
# Kurtosis: -1.350272
# Skewness: -0.191327
# Kurtosis: -0.141414
# Skewness: -0.242790
# Kurtosis: -0.508943
# Skewness: 0.555586
# Kurtosis: 2.621704
# Skewness: 4.568630
# Kurtosis: 25.822987
# Skewness: -1.320130
# Kurtosis: 1.040087
# Skewness: 1.522983
# Kurtosis: 2.462551
# Skewness: 1.473460
# Kurtosis: 1.596467
# Skewness: 1.140243
# Kurtosis: 0.862325
# Skewness: 1.452745
# Kurtosis: 1.956017
# Skewness: 1.147593
# Kurtosis: 0.654985
# Skewness: -0.258846
# Kurtosis: -1.949109

# %% [markdown]
# #### Important Observations
# * Temperature:-close to normal distribution
# * Ws:-close to normal distribution
# * Rain:-It is positively skewed and it has skinny tail which means there are more chances of outlier
# * FFMC:It is negatively skewed and has center stretched tails means most of the data points are present around the mean.

# %% [markdown]
# # Bivariate

# %%
df['year'].std()#we can drop this feature as this is not explicitly effecting the target
# Out:
# 0.0

# %%
df['FWI'].hist(by=df['month'], layout=(1,4), figsize=(16,2))
# Out:
# array([<AxesSubplot:title={'center':'6.0'}>,
#        <AxesSubplot:title={'center':'7.0'}>,
#        <AxesSubplot:title={'center':'8.0'}>,
#        <AxesSubplot:title={'center':'9.0'}>], dtype=object)

# %%
df.groupby('month')['FWI'].median().plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# #### Observation :-FWI is higher in month of august compare to june,july and september ,June and September has least FWI

# %%
for i in df.columns:
    if i!='year' and i!='FWI':
        sns.scatterplot(df[i],df['FWI'])
        plt.xlabel(i)
        plt.ylabel('FWI')
        plt.show()

# %%
sns
# Out:
# <module 'seaborn' from 'c:\\users\\1672040\\appdata\\local\\programs\\python\\python37\\lib\\site-packages\\seaborn\\__init__.py'>

# %%
plt.figure(figsize=(10,5))
sns.barplot('Temperature',y='FWI',hue='Classes',data=df,)
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='FWI'>

# %%
sns.histplot(df['FWI'])
# Out:
# <AxesSubplot:xlabel='FWI', ylabel='Count'>

# %%
df[(df['FWI']>0) & (df['FWI']<2.5)]['Classes'].value_counts()
# Out:
# 0    84
# 1     2
# Name: Classes, dtype: int64

# %% [markdown]
# #### Observation : 30 % of data has FWI index below 2.5 and chances of catching fire for this instances are less than 2.5%

# %%
df[df['FWI']>10]['Classes'].value_counts()
# Out:
# 1    71
# Name: Classes, dtype: int64

# %% [markdown]
# #### observation:Chances of catching fire is 100% for FWI greater than 10

# %%
sns.pairplot(df[['FFMC','DMC','DC','ISI','BUI','FWI']])

# %%
plt.figure(figsize=(14,12))
df1=df.drop(columns='year')
sns.heatmap(df1.corr(),linewidths=.1,cmap="YlGnBu", annot=True)

plt.yticks(rotation=0);

# %% [markdown]
# #### Observations:
# FWI has high positive correlation with `FFMC`,`DMC`,`DC`,`ISI`,`BUI`,`FWI` ,`month`

# %% [markdown]
# # Feature Enginnering

# %%
for i in df.columns:
    print(" Standard Deviation for",i,df[i].std(),"and unique value is",len(df[i].unique()))
# Out:
#  Standard Deviation for day 8.84255216762635 and unique value is 31
#  Standard Deviation for month 1.1147934085625215 and unique value is 4
#  Standard Deviation for year 0.0 and unique value is 1
#  Standard Deviation for Temperature 3.6280394810147514 and unique value is 19
#  Standard Deviation for RH 14.828160120227333 and unique value is 62
#  Standard Deviation for Ws 2.8113853094929575 and unique value is 18
#  Standard Deviation for Rain 2.003206795506829 and unique value is 39
#  Standard Deviation for FFMC 14.349641256730104 and unique value is 173
#  Standard Deviation for DMC 12.393039751223832 and unique value is 165
#  Standard Deviation for DC 47.66560598458993 and unique value is 197
#  Standard Deviation for ISI 4.154233833368701 and unique value is 106
#  Standard Deviation for BUI 14.228421131468963 and unique value is 173
#  Standard Deviation for FWI 7.440567726345277 and unique value is 125
# ...

# %% [markdown]
# #### Since Std for `Year` feature is zero and unique value is one ,we can drop that column

# %%
df.drop(columns='year',inplace=True)

# %% [markdown]
# ### `Outlier`

# %%
df.describe()
# Out:
# 0             day       month  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.000000  243.000000  243.000000
# mean    15.761317    7.502058    32.152263   62.041152   15.493827
# std      8.842552    1.114793     3.628039   14.828160    2.811385
# min      1.000000    6.000000    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000    35.000000   73.500000   17.000000
# max     31.000000    9.000000    42.000000   90.000000   29.000000
#
# 0            Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# std      2.003207   14.349641   12.393040   47.665606    4.154234   14.228421
# ...

# %% [markdown]
# ### There is large differnece between 75th and 100th percentile in `Rain`,`DMC`,`DC` and` BUI ` Feature,this indicates there are extreme values-Outliers in our data set

# %%
for i in df.columns:
    plt.figure(figsize=(16,6))
    sns.boxplot(df[i])
    plt.show()

# %%
f=['Rain','DMC','DC','BUI']
for i in f:
    plt.figure(figsize=(16,6))
    sns.boxplot(x='month',y=i,data=df)
    sns.swarmplot(x='month',y=i,data=df,color=".25")
    plt.show()

# %%
sns.barplot(x='month',y='Rain',data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='Rain'>

# %%
def detect_outliers_iqr(data):
    data = sorted(data)
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    IQR = q3-q1
    lwr_bound = q1-(1.5*IQR)
    upr_bound = q3+(1.5*IQR)
    return lwr_bound,upr_bound
lwr,upper=detect_outliers_iqr(df['Rain'])
print("lower Bound:",lwr,"Upper Bound:",upper)
print(len(df[(df['Rain']>lwr)&(df['Rain']<upper)]))
print(df[(df['Rain']>lwr)&(df['Rain']<upper)]['Classes'].value_counts())
# Out:
# lower Bound: -0.75 Upper Bound: 1.25
# 208
# 1    135
# 0     73
# Name: Classes, dtype: int64

# %%
sns.scatterplot(x=df['Rain'],y=df['FWI'])
# Out:
# <AxesSubplot:xlabel='Rain', ylabel='FWI'>

# %%
sns.scatterplot(y=df[(df['Rain']>lwr)&(df['Rain']<upper)]['FWI'],x=df[(df['Rain']>lwr)&(df['Rain']<upper)]['Rain'])
# Out:
# <AxesSubplot:xlabel='Rain', ylabel='FWI'>

# %%
from sklearn.cluster import DBSCAN
data=df[['Rain','FWI']]
dscan = DBSCAN(eps = 0.4, min_samples = 5).fit(data)
colors = dscan.labels_
plt.figure(figsize=(16,6))
plt.scatter(data["Rain"], data["FWI"], c = colors)

# %%
outliers = data[dscan.labels_ == -1]
outliers
# Out:
# 0    Rain   FWI
# 3    13.1   0.1
# 4     2.5   0.0
# 15    3.1   0.1
# 25    0.0   8.4
# 28    0.0  13.9
# 51    0.0   8.8
# 58    0.0  11.3
# 80    0.0  17.2
# 81    0.0  16.8
# 82    0.0  18.4
# 83    0.0  20.4
# 84    0.0  22.3
# 85    0.0  20.9
# 86    0.0  20.3
# 89    0.0  19.9
# 90    0.0  30.2
# 91    0.8   4.2
# 92   16.8   0.3
# 93    7.2   0.1
# 94   10.1   0.0
# 95    3.8   0.0
# 105   4.6   0.0
# 106   8.3   0.1
# 117   5.8   0.1
# 126   4.0   0.2
# 135   0.0  16.7
# 137   2.0   0.9
# 141   4.7   0.4
# 142   8.7   0.4
# 143   4.5   0.4
# 146   1.1   1.2
# 152   0.0  18.4
# 153   0.6   7.2
# 154   1.7   2.2
# 162   6.0   3.0
# 163   1.9   3.1
# 164   3.8   1.3
# 165   2.9   0.8
# 167   0.6   4.7
# 169   0.0  14.1
# 172   0.0   9.1
# 174   0.0  17.3
# 175   0.0  30.0
# 176   0.0  25.4
# 178   1.1   2.5
# 182   0.0   9.0
# 188   0.0  19.5
# 189   0.0  20.9
# 191   3.1   0.8
# 192   2.9   0.6
# 196   0.0  21.6
# 197   0.4  18.8
# 202   0.0  24.0
# 203   0.0  26.3
# ...

# %% [markdown]
# #### From Above analysis it's evident that Rain in mm does has the direct relationship with FWI and we cannot treat it has noise or outlier

# %%
x=df.drop(columns='FWI')
y=df['FWI']
vif=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
VIF=pd.DataFrame()
VIF['Features']=x.columns
VIF['VIF']=vif
VIF
# Out:
#        Features         VIF
# 0           day    6.074737
# 1         month   41.215572
# 2   Temperature  110.184625
# 3            RH   34.989208
# 4            Ws   37.221042
# 5          Rain    1.728686
# 6          FFMC  124.495516
# 7           DMC  186.508636
# 8            DC   51.904354
# 9           ISI   11.417290
# 10          BUI  382.257260
# 11      Classes    7.302584

# %%
#import statsmodels.api as sm

# %%
#sm.OLS(y,x).fit()

# %%
#model.summary()

# %% [markdown]
# ### Saving the model on DB

# %%
client = pymongo.MongoClient("mongodb+srv://ashishshukla23sep:mm1332647@cluster0.o1yzz.mongodb.net/?retryWrites=true&w=majority")

# %%
DB_NAME="Algerian_forest"
dataBase = client[DB_NAME]

# %%
collection_name="Training_data"
collection=dataBase[collection_name]

# %%
dic=df.to_dict()
collection.insert_one(dic)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-113-4607c5fdfd5b> in <module>
#       1 dic=df.to_dict()
# ----> 2 collection.insert_one(dic)
#
# c:\users\1672040\appdata\local\programs\python\python37\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     696                          write_concern=write_concern,
#     697                          bypass_doc_val=bypass_document_validation,
# --> 698                          session=session),
#     699             write_concern.acknowledged)
#     700
#
# c:\users\1672040\appdata\local\programs\python\python37\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     610             return self._insert_one(
# ...

# %% [markdown]
# # Regression Modeling

# %%
from sklearn.linear_model import LinearRegression
from xgboost.sklearn import XGBRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import ridge_regression,Lasso
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

#Spliting nd tuning the module
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV,StratifiedShuffleSplit,ShuffleSplit


#metrics evaluation
from sklearn.metrics import mean_squared_error,r2_score,classification_report

# %%
models={"LR":LinearRegression(),
"XGBR":XGBRegressor(),
"SGDR":SGDRegressor(),
"ELNR":ElasticNet(),
"GBR":GradientBoostingRegressor(),
"SVR":SVR(),
"RFR":RandomForestRegressor(random_state=10),
"DTR":DecisionTreeRegressor(),
"LASSO":Lasso()}

# %%
#Data spliting
x=df.drop(columns='FWI')
y=df['FWI']

# %% [markdown]
# ### Model Evaluation function

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()

# %%
model_evel={}
def model_evalution(x,y,models,sss=False,Stdsclr=False):
    if Stdsclr:
        if sss:
            sss=StratifiedShuffleSplit(n_splits=1,random_state=10,test_size=0.2)
            train_index,test_index = next(sss.split(df.drop(columns='Classes'),df['Classes']))
            x_train,x_test=x.iloc[train_index],x.iloc[test_index]
            y_train,y_test=y.iloc[train_index],y.iloc[test_index]
            x_train=scalar.fit_transform(x_train)
            x_test=scalar.transform(x_test)
        else:
            x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)
            x_train=scalar.fit_transform(x_train)
            x_test=scalar.transform(x_test)
    else:
        if sss:
            sss=StratifiedShuffleSplit(n_splits=1,random_state=10,test_size=0.2)
            train_index,test_index = next(sss.split(df.drop(columns='Classes'),df['Classes']))
            x_train,x_test=x.iloc[train_index],x.iloc[test_index]
            y_train,y_test=y.iloc[train_index],y.iloc[test_index]
            
        else:
            x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)
            
    for model_name,model in models.items():
        score={}
        model.fit(x_train,y_train)
        y_pred=model.predict(x_test)
        score["mse_score"]=mean_squared_error(y_test,y_pred)
        score["r2_score_test"]=r2_score(y_test,y_pred)
        score["r2_score_train"]=model.score(x_train,y_train)
        score["Croos_val_score"]=cross_val_score(model,x,y,cv=5,scoring='r2').mean()
        model_evel[model_name]=score
    return model_evel

# %% [markdown]
# #### `SCALED DATA WITH TRAIN_TEST_SPLIT`

# %%
all_score=model_evalution(x,y,models,Stdsclr=True)

# %%
pd.DataFrame(all_score)
# Out:
#                        LR      XGBR          SGDR      ELNR       GBR  \
# mse_score        1.044308  1.322034  1.110465e+00  4.923066  0.740253
# r2_score_test    0.974023  0.967115  9.723774e-01  0.877540  0.981586
# r2_score_train   0.975376  1.000000  9.739874e-01  0.914134  0.999693
# Croos_val_score  0.949324  0.969541 -6.985132e+24  0.956066  0.971089
#
#                       SVR       RFR       DTR     LASSO
# mse_score        3.422158  0.992764  3.642857  1.910732
# r2_score_test    0.914874  0.975305  0.909385  0.952471
# r2_score_train   0.875001  0.995935  1.000000  0.949321
# Croos_val_score  0.672242  0.973116  0.928677  0.953729

# %% [markdown]
# #### `SCALED DATA WITH STRATIFIEDSHUFFLESPLIT`

# %%
all_score=model_evalution(x,y,models,Stdsclr=True,sss=True)

# %%
pd.DataFrame(all_score)
# Out:
#                        LR      XGBR          SGDR      ELNR       GBR  \
# mse_score        0.726728  2.185922  7.531805e-01  5.707183  1.624933
# r2_score_test    0.987789  0.963269  9.873441e-01  0.904100  0.972696
# r2_score_train   0.972161  1.000000  9.708054e-01  0.908664  0.999708
# Croos_val_score  0.949324  0.969541 -1.113725e+24  0.956066  0.969448
#
#                        SVR       RFR       DTR     LASSO
# mse_score        10.763335  1.489615  5.622653  2.395057
# r2_score_test     0.819140  0.974969  0.905521  0.959755
# r2_score_train    0.869614  0.996596  1.000000  0.944788
# Croos_val_score   0.672242  0.973116  0.915186  0.953729

# %% [markdown]
# ##### Non_scaled data with `train_test_split`

# %%
all_score=model_evalution(x,y,models)

# %%
pd.DataFrame(all_score)
# Out:
#                        LR      XGBR          SGDR      ELNR       GBR  \
# mse_score        1.044308  1.322466  2.107458e+25  1.397296  0.769914
# r2_score_test    0.974023  0.967104 -5.242263e+23  0.965243  0.980849
# r2_score_train   0.975376  1.000000 -5.685139e+23  0.970884  0.999693
# Croos_val_score  0.949324  0.969541 -3.261575e+24  0.956066  0.971460
#
#                        SVR       RFR       DTR     LASSO
# mse_score        11.692697  0.976423  3.919592  1.327909
# r2_score_test     0.709146  0.975712  0.902501  0.966969
# r2_score_train    0.791687  0.995938  1.000000  0.970818
# Croos_val_score   0.672242  0.973116  0.925393  0.953729

# %% [markdown]
# ##### Non_scaled data with with `StratifiedShuffleSplit`

# %%
all_score=model_evalution(x,y,models,sss=True)

# %%
pd.DataFrame(all_score)
# Out:
#                        LR      XGBR          SGDR      ELNR       GBR  \
# mse_score        0.726728  2.186335  2.333147e+26  1.015411  1.736112
# r2_score_test    0.987789  0.963262 -3.920464e+24  0.982938  0.970828
# r2_score_train   0.972161  1.000000 -5.611346e+24  0.967214  0.999708
# Croos_val_score  0.949324  0.969541 -3.813414e+24  0.956066  0.969737
#
#                        SVR       RFR       DTR     LASSO
# mse_score        20.067976  1.484555  5.610204  1.012186
# r2_score_test     0.662791  0.975055  0.905730  0.982992
# r2_score_train    0.783492  0.996556  1.000000  0.967136
# Croos_val_score   0.672242  0.973116  0.923081  0.953729

# %% [markdown]
# #### `GradientBoostingRegressor` with`train_test_split` gives highest r2_score_test of ``0.975055``

# %% [markdown]
# ## Hyper parameter tunning for `GradientBoostingRegressor`

# %%
estimator = GradientBoostingRegressor(random_state=10)
param_grid = {'learning_rate': [0.01,0.02,0.03,0.04],
                  'subsample'    : [0.9, 0.5, 0.2, 0.1],
                  'n_estimators' : [100,500,1000, 1500],
                  'max_depth'    : [4,6,8,10]
                 }

# %%
gv_gbr=GridSearchCV(estimator=estimator,param_grid=param_grid)

# %%
x=df.drop(columns='FWI')
y=df['FWI']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)
x_train=scalar.fit_transform(x_train)
x_test=scalar.transform(x_test)

# %%
pickle.dump(scalar, open('scaler_reg.pkl','wb'))

# %%
gv_gbr.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=GradientBoostingRegressor(random_state=10),
#              param_grid={'learning_rate': [0.01, 0.02, 0.03, 0.04],
#                          'max_depth': [4, 6, 8, 10],
#                          'n_estimators': [100, 500, 1000, 1500],
#                          'subsample': [0.9, 0.5, 0.2, 0.1]})

# %%
gv_gbr.best_params_
# Out:
# {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500, 'subsample': 0.2}

# %%
y_pred=gv_gbr.predict(x_test)
mean_squared_error(y_test,y_pred)
# Out:
# 0.22846012979962008

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9943170970705232

# %%
with open('reg_model_pkl', 'wb') as files:
    joblib.dump(gv_gbr, files)

# %%
with open('reg_model_pkl' , 'rb') as f:
    model = joblib.load(f)

# %%
y_pred_T=model.predict(x_test)

# %%
r2_score(y_test,y_pred_T)
# Out:
# 0.9943170970705232

# %% [markdown]
# # Classification Modeling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %%
models_clf={"LR":LogisticRegression(),
           "SVC":SVC(),
           "KNNC":KNeighborsClassifier(),
           "DTC":DecisionTreeClassifier(),
           "RFC":RandomForestClassifier(),
           "GNB":GaussianNB()}

# %%
x=df.drop(columns='Classes')
y=df["Classes"]

# %%
def model_evalution_clf(x,y,models,sss=False):
    if sss:
        sss=StratifiedShuffleSplit(n_splits=1,random_state=10,test_size=0.2)
        train_index,test_index = next(sss.split(df.drop(columns='Classes'),df['Classes']))
        x_train,x_test=x.iloc[train_index],x.iloc[test_index]
        y_train,y_test=y.iloc[train_index],y.iloc[test_index]
        x_train=scalar.fit_transform(x_train)
        x_test=scalar.transform(x_test)
    else:
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)
        x_train=scalar.fit_transform(x_train)
        x_test=scalar.transform(x_test)
    for model_name,model in models.items():
        print(model)
        print("----------------------------------------------------------------")
        model.fit(x_train,y_train)
        y_pred=model.predict(x_test)
        print("\n",classification_report(y_test,y_pred))
        print("Cross_Val_score",cross_val_score(model,x,y,cv=5).mean())
        print("################################################################")
        
    return model_evel

# %% [markdown]
# #### Train_test_split

# %%
all_eval_clf=model_evalution_clf(x,y,models_clf)
# Out:
# LogisticRegression()
# ----------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        20
#            1       1.00      0.93      0.96        29
#
#     accuracy                           0.96        49
#    macro avg       0.95      0.97      0.96        49
# weighted avg       0.96      0.96      0.96        49
#
# Cross_Val_score 0.9671768707482993
# ################################################################
# SVC()
# ----------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        20
#            1       1.00      0.93      0.96        29
#
#     accuracy                           0.96        49
#    macro avg       0.95      0.97      0.96        49
# weighted avg       0.96      0.96      0.96        49
#
# Cross_Val_score 0.8974489795918368
# ...

# %% [markdown]
# #### StratifiedShuffleSplit

# %%
all_eval_clf=model_evalution_clf(x,y,models_clf,sss=True)
# Out:
# LogisticRegression()
# ----------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        21
#            1       1.00      1.00      1.00        28
#
#     accuracy                           1.00        49
#    macro avg       1.00      1.00      1.00        49
# weighted avg       1.00      1.00      1.00        49
#
# Cross_Val_score 0.9671768707482993
# ################################################################
# SVC()
# ----------------------------------------------------------------
#
#                precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        21
#            1       0.96      0.96      0.96        28
#
#     accuracy                           0.96        49
#    macro avg       0.96      0.96      0.96        49
# weighted avg       0.96      0.96      0.96        49
#
# Cross_Val_score 0.8974489795918368
# ...

# %% [markdown]
# #### `RandomForestClassifier` with`StratifiedShuffleSplit` gives highest Cross_Val_score of ``0.979591``

# %%
rfc=RandomForestClassifier(random_state=10)
x=df.drop(columns='Classes')
y=df["Classes"]
param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

# %%
x=df.drop(columns='Classes')
y=df["Classes"]
sss=StratifiedShuffleSplit(n_splits=1,random_state=10,test_size=0.2)
train_index,test_index = next(sss.split(df.drop(columns='Classes'),df['Classes']))
x_train,x_test=x.iloc[train_index],x.iloc[test_index]
y_train,y_test=y.iloc[train_index],y.iloc[test_index]
x_train=scalar.fit_transform(x_train)
x_test=scalar.transform(x_test)
print(x_train.shape)
print(x_test.shape)
# Out:
# (194, 12)
# (49, 12)

# %%
scalar.mean_
# Out:
# array([15.95876289,  7.54123711, 32.10824742, 62.74226804, 15.51546392,
#         0.82680412, 77.74639175, 14.86494845, 51.18402062,  4.6257732 ,
#        17.00721649,  6.97010309])

# %%
np.sqrt(scalar.var_)
# Out:
# array([ 8.85556209,  1.10800765,  3.61606296, 14.44740076,  2.80688918,
#         2.13522328, 14.21581856, 12.49395352, 49.28376076,  3.98956831,
#        14.48400645,  7.34896956])

# %%
gv_clf=GridSearchCV(estimator=rfc,param_grid=param_grid)

# %%
gv_clf.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(random_state=10),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 500]})

# %%
gv_clf.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': 'auto',
#  'n_estimators': 500}

# %%
y_pred_clf=gv_clf.predict(x_test)
print(classification_report(y_test,y_pred_clf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        21
#            1       1.00      1.00      1.00        28
#
#     accuracy                           1.00        49
#    macro avg       1.00      1.00      1.00        49
# weighted avg       1.00      1.00      1.00        49

# %%
gv_clf.predict([x_test[0]])
# Out:
# array([1])

# %%
y_test[205]
# Out:
# 1

# %%
with open('clf_model_pkl', 'wb') as files:
    joblib.dump(gv_clf, files)

# %%
s=pd.Series(np.random.randn(4))

# %%
df.to_csv('test.csv',index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\1672040\\Desktop\\project\\Algerian Forest'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-128-366e5669476a> in <module>
# ----> 1 os.path.dirname()
#
# TypeError: dirname() missing 1 required positional argument: 'p'

# %%
ALLOWED_EXTENSIONS = set(['csv'])

def allowed_file(filename):
    return '.' in filename and filename.rsplit('.', 1)[1].lower() in ALLOWED_EXTENSIONS

# %%
allowed_file("myfile.csv")
# Out:
# True

# %%
"myfile.csv".split('.', 1)[1]
# Out:
# 'csv'

# %%
ALLOWED_EXTENSIONS
# Out:
# {'csv'}
